# %% [markdown]
# **复习：**在前面我们已经学习了Pandas基础，第二章我们开始进入数据分析的业务部分，在第二章第一节的内容中，我们学习了**数据的清洗**，这一部分十分重要，只有数据变得相对干净，我们之后对数据的分析才可以更有力。而这一节，我们要做的是数据重构，数据重构依旧属于数据理解（准备）的范围。

# %% [markdown]
# 【第二章第二节总结】
# 主要学习了 文件直接的连接，类似于sql中的join，join是通过索引连接，merge是通过值连接，concat可以垂直堆叠，stack是把所有列和值一一堆叠出来

# %% [markdown]
# #### 开始之前，导入numpy、pandas包和数据

# %%
# 导入基本库
import numpy as np
import pandas as pd

# %%
# 载入data文件中的:train-left-up.csv
df=pd.read_csv('/Users/shikun/Documents/python/动手数据分析/第二章项目集合/data/train-left-up.csv')
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina

# %% [markdown]
# # 2 第二章：数据重构

# %% [markdown]
# ### 2.4 数据的合并

# %% [markdown]
# #### 2.4.1 任务一：将data文件夹里面的所有数据都载入，观察数据的之间的关系

# %%
#写入代码
text_left_up = pd.read_csv("data/train-left-up.csv")
text_left_down = pd.read_csv("data/train-left-down.csv")
text_right_up = pd.read_csv("data/train-right-up.csv")
text_right_down = pd.read_csv("data/train-right-down.csv")

# %%
#写入代码
text_left_up.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry

# %%
text_left_down.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name
# 0          440         0       2       Kvillner, Mr. Johan Henrik Johannesson
# 1          441         1       2  Hart, Mrs. Benjamin (Esther Ada Bloomfield)
# 2          442         0       3                              Hampe, Mr. Leon
# 3          443         0       3                    Petterson, Mr. Johan Emil
# 4          444         1       2                    Reynaldo, Ms. Encarnacion

# %%
text_right_up.head()
# Out:
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
text_right_down.head(10)
# Out:
#       Sex   Age  SibSp  Parch        Ticket     Fare Cabin Embarked
# 0    male  31.0      0      0    C.A. 18723  10.5000   NaN        S
# 1  female  45.0      1      1  F.C.C. 13529  26.2500   NaN        S
# 2    male  20.0      0      0        345769   9.5000   NaN        S
# 3    male  25.0      1      0        347076   7.7750   NaN        S
# 4  female  28.0      0      0        230434  13.0000   NaN        S
# 5    male   NaN      0      0         65306   8.1125   NaN        S
# 6    male   4.0      0      2         33638  81.8583   A34        S
# 7  female  13.0      0      1        250644  19.5000   NaN        S
# 8    male  34.0      0      0        113794  26.5500   NaN        S
# 9  female   5.0      2      1          2666  19.2583   NaN        C

# %% [markdown]
# 【提示】结合之前我们加载的train.csv数据，大致预测一下上面的数据是什么

# %% [markdown]
# #### 2.4.2：任务二：使用concat方法：将数据train-left-up.csv和train-right-up.csv横向合并为一张表，并保存这张表为result_up

# %%
#写入代码
result_up=pd.concat([text_left_up,text_right_up],axis=1)
result_up.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### 2.4.3 任务三：使用concat方法：将train-left-down和train-right-down横向合并为一张表，并保存这张表为result_down。然后将上边的result_up和result_down纵向合并为result。

# %%
#写入代码
result_down=pd.concat([text_left_down,text_right_down],axis=1)
result=pd.concat([result_up,result_down],axis=0)
result.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 447          887         0       2                     Montvila, Rev. Juozas
# 448          888         1       1              Graham, Miss. Margaret Edith
# 449          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 450          890         1       1                     Behr, Mr. Karl Howell
# 451          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 447    male  27.0      0      0      211536  13.00   NaN        S
# 448  female  19.0      0      0      112053  30.00   B42        S
# 449  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 450    male  26.0      0      0      111369  30.00  C148        C
# 451    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# #### 2.4.4 任务四：使用DataFrame自带的方法join方法和append：完成任务二和任务三的任务

# %%
#写入代码
result_up=text_left_up.join(text_right_up)
result_down=text_left_down.join(text_right_down)
result=result_up.join(result_down,axis=0)
result.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/fb/pjr875xs7vxb3pgxtr8wm9wr0000gn/T/ipykernel_34065/1721847096.py in <module>
#       2 result_up=text_left_up.join(text_right_up)
#       3 result_down=text_left_down.join(text_right_down)
# ----> 4 result=result_up.join(result_down,axis=0)
#       5 result.head()
#
# TypeError: join() got an unexpected keyword argument 'axis'

# %% [markdown]
# #### 2.4.5 任务五：使用Panads的merge方法和DataFrame的append方法：完成任务二和任务三的任务

# %%
#写入代码
result_up=text_left_up.merge(text_right_up,left_index=True,right_index=True)
result_down=text_left_down.merge(text_right_down,left_index=True,right_index=True)
result=result_up.append(result_down)
result.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 【思考】对比merge、join以及concat的方法的不同以及相同。思考一下在任务四和任务五的情况下，为什么都要求使用DataFrame的append方法，如何只要求使用merge或者join可不可以完成任务四和任务五呢？

# %% [markdown]
# merge可以是列，join是行索引，join如果达到merge的效果，可以使用set_index后再连接，concat可以垂直堆叠

# %% [markdown]
# #### 2.4.6 任务六：完成的数据保存为result.csv

# %%
#写入代码
result.to_csv('result.csv')

# %% [markdown]
# ### 2.5 换一种角度看数据

# %% [markdown]
# #### 2.5.1 任务一：将我们的数据变为Series类型的数据

# %%
#写入代码 #stack是堆栈
series_result=result.stack().head(20)
series_result
# Out:
# 0  PassengerId                                                    1
#    Survived                                                       0
#    Pclass                                                         3
#    Name                                     Braund, Mr. Owen Harris
#    Sex                                                         male
#    Age                                                         22.0
#    SibSp                                                          1
#    Parch                                                          0
#    Ticket                                                 A/5 21171
#    Fare                                                        7.25
#    Embarked                                                       S
# 1  PassengerId                                                    2
#    Survived                                                       1
#    Pclass                                                         1
# ...

# %%
#写入代码
